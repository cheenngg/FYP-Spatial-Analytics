# %% [markdown]
# # Ordinary Kriging

# %% [markdown]
# Referenced Code Notebook:
# https://colab.research.google.com/drive/1mZDVJ-RioBc4QHHpe2HBNJrx8sJ4-1Lw#scrollTo=TBAAD0nX-7tT
#
# Useful paper on OK:
# https://iopscience.iop.org/article/10.1088/1742-6596/1434/1/012025/pdf
#
# PyKrige:
# https://geostat-framework.readthedocs.io/projects/pykrige/en/latest/examples/08_krige_cv.html#sphx-glr-examples-08-krige-cv-py
#
# https://github.com/GeoStat-Framework/PyKrige/blob/main/src/pykrige/ok.py
#
# https://github.com/GeoStat-Framework/PyKrige/blob/main/src/pykrige/variogram_models.py

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pykrige.kriging_tools as kt
from pykrige.ok import OrdinaryKriging

# %%
crimes_df = pd.read_csv("crimes_processed.csv")
meuse_df = pd.read_csv("meuse_processed.csv")

# %%
meuse_df
# Out:
#           x       y  cadmium  copper  lead  zinc   elev      dist    om  \
# 0    181072  333611     11.7      85   299  1022  7.909  0.001358  13.6
# 1    181025  333558      8.6      81   277  1141  6.983  0.012224  14.0
# 2    181165  333537      6.5      68   199   640  7.800  0.103029  13.0
# 3    181298  333484      2.6      81   116   257  7.655  0.190094   8.0
# 4    181307  333330      2.8      48   117   269  7.480  0.277090   8.7
# ..      ...     ...      ...     ...   ...   ...    ...       ...   ...
# 150  179184  330182      0.8      20    49   166  8.128  0.423837   4.7
# 151  179085  330292      3.1      39   173   496  8.577  0.423837   9.1
# 152  178875  330311      2.1      31   119   342  8.429  0.277090   6.5
# 153  179466  330381      0.8      21    51   162  9.406  0.358606   5.7
# 154  180627  330190      2.7      27   124   375  8.261  0.012224   5.5
#
#      ffreq  soil  lime landuse  dist.m
# 0        1     1     1      Ah      50
# 1        1     1     1      Ah      30
# 2        1     1     1      Ah     150
# 3        1     2     0      Ga     270
# 4        1     2     0      Ah     380
# ..     ...   ...   ...     ...     ...
# 150      3     1     0      Am     540
# 151      3     1     0      Ah     520
# 152      3     1     0      Ah     350
# 153      3     1     0       W     460
# 154      3     3     0       W      40
#
# [155 rows x 14 columns]

# %%
meuse_df.describe()
# Out:
#                    x              y     cadmium      copper        lead  \
# count     155.000000     155.000000  155.000000  155.000000  155.000000
# mean   180004.600000  331634.935484    3.245806   40.316129  153.361290
# std       746.039775    1047.746801    3.523746   23.680436  111.320054
# min    178605.000000  329714.000000    0.200000   14.000000   37.000000
# 25%    179371.000000  330762.000000    0.800000   23.000000   72.500000
# 50%    179991.000000  331633.000000    2.100000   31.000000  123.000000
# 75%    180629.500000  332463.000000    3.850000   49.500000  207.000000
# max    181390.000000  333611.000000   18.100000  128.000000  654.000000
#
#               zinc        elev        dist          om       ffreq  \
# count   155.000000  155.000000  155.000000  153.000000  155.000000
# mean    469.716129    8.165394    0.240017    7.478431    1.606452
# std     367.073788    1.058657    0.197702    3.432966    0.734111
# min     113.000000    5.180000    0.000000    1.000000    1.000000
# 25%     198.000000    7.546000    0.075687    5.300000    1.000000
# 50%     326.000000    8.180000    0.211843    6.900000    1.000000
# 75%     674.500000    8.955000    0.364067    9.000000    2.000000
# max    1839.000000   10.520000    0.880389   17.000000    3.000000
#
#              soil        lime       dist.m
# count  155.000000  155.000000   155.000000
# mean     1.451613    0.283871   290.322581
# std      0.636483    0.452336   226.799927
# min      1.000000    0.000000    10.000000
# 25%      1.000000    0.000000    80.000000
# 50%      1.000000    0.000000   270.000000
# 75%      2.000000    1.000000   450.000000
# max      3.000000    1.000000  1000.000000

# %%
x = np.array(meuse_df['x'])
y = np.array(meuse_df['y'])
zinc = np.array(meuse_df['zinc'])

# %%
cax = plt.scatter(x, y, c=zinc)
cbar = plt.colorbar(cax, fraction=0.03)
plt.title('Measured Zinc Levels')
# Out:
# Text(0.5, 1.0, 'Measured Zinc Levels')

# %%
OK = OrdinaryKriging(
    x, 
    y, 
    zinc, 
    variogram_model='exponential',
    verbose=True,
    enable_plotting=True,
    nlags=10,
)
# Out:
# Plotting Enabled
#
# Adjusting data for anisotropy...
# Initializing variogram model...
# Coordinates type: 'euclidean'
#
# Using 'exponential' Variogram Model
# Partial Sill: 100113.19810744449
# Full Sill: 136584.63411320242
# Range: 954.8407332703556
# Nugget: 36471.436005757925
# Calculating statistics on variogram model fit...

# %%
OK.variogram_model_parameters
# Out:
# array([100113.19810744,    954.84073327,  36471.43600576])

# %%
gridx = np.arange(178605, 181390, 10, dtype='float64')
gridy = np.arange(329714, 333611, 10, dtype='float64')
zstar, ss = OK.execute("grid", gridx, gridy)
# Out:
# Executing Ordinary Kriging...

# %%
# Create a figure with a specific size
fig = plt.figure(figsize=(8, 6))

# Plot the data
cax = plt.imshow(zstar, extent=(178605, 181450, 329714, 333611), origin='lower')
plt.scatter(x, y, c='k', marker='.')

# Set the limits of the x-axis to increase its length
plt.xlim(178700, 181450)

# Add colorbar
cbar = plt.colorbar(cax)

# Add labels and title
plt.title('Zinc estimate')

# Show the plot
plt.show()

# %%
# Create a figure with a specific size
fig = plt.figure(figsize=(8, 6))

# Plot the data
cax = plt.imshow(np.sqrt(ss), extent=(178605, 181450, 329714, 333611), origin='lower', vmin = 0)
plt.scatter(x, y, c='k', marker='.')

# Set the limits of the x-axis to increase its length
plt.xlim(178700, 181450)

# Add colorbar
cbar = plt.colorbar(cax)

# Add labels and title
plt.title('Zinc standard devation')

# Show the plot
plt.show()
