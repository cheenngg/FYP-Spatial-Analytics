# %%
import pandas as pd
import os
from pathlib import Path
import Data
import coordinates

# %%
currpath = os.getcwd()
mypath = Path().absolute().parent # each '.parent' goes one level up - vary as required
#print(mypath)
#os.chdir(mypath)
os.chdir(os.path.dirname(os.path.abspath("meuse_data.csv")))
print(Path().absolute())
# Out:
# C:\Users\chloe\OneDrive\AY2023 & 2024 FYP\FYP-Code\FYP-Spatial-Analytics

# %%
df = pd.read_csv("Data/meuse_data.csv")
df2 = df
df2.describe()
# Out:
#                    x              y     cadmium      copper        lead  \
# count     155.000000     155.000000  155.000000  155.000000  155.000000
# mean   180004.600000  331634.935484    3.245806   40.316129  153.361290
# std       746.039775    1047.746801    3.523746   23.680436  111.320054
# min    178605.000000  329714.000000    0.200000   14.000000   37.000000
# 25%    179371.000000  330762.000000    0.800000   23.000000   72.500000
# 50%    179991.000000  331633.000000    2.100000   31.000000  123.000000
# 75%    180629.500000  332463.000000    3.850000   49.500000  207.000000
# max    181390.000000  333611.000000   18.100000  128.000000  654.000000
#
#               zinc        elev        dist          om       ffreq  \
# count   155.000000  155.000000  155.000000  153.000000  155.000000
# mean    469.716129    8.165394    0.240017    7.478431    1.606452
# std     367.073788    1.058657    0.197702    3.432966    0.734111
# ...

# %%
import geoplot as gplt
import geopandas as gpd
import geoplot.crs as gcrs
import imageio
import matplotlib.pyplot as plt
import mapclassify as mc
import numpy as np
import shapely

# %%
from shapely.geometry import Point

collision_points = df2.apply(
    lambda srs: Point(float(df2['x']), float(df2['y'])),
    axis='columns'
)
collision_points
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 from shapely.geometry import Point
# ----> 3 collision_points = df2.apply(
#       4     lambda srs: Point(float(df2['x']), float(df2['y'])),
#       5     axis='columns'
#       6 )
#       7 collision_points
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:9568, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9557 from pandas.core.apply import frame_apply
#    9559 op = frame_apply(
#    9560     self,
#    9561     func=func,
#    (...)
#    9566     kwargs=kwargs,
#    9567 )
# -> 9568 return op.apply().__finalize__(self, method="apply")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\apply.py:764, in FrameApply.apply(self)
#     761 elif self.raw:
#     762     return self.apply_raw()
# --> 764 return self.apply_standard()
#
# ...
